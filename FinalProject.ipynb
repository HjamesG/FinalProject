# %%
import random

class worldMap():
    def __init__(self):
        # this map has a list at each "room" These lists will hold the map layout, booleans for directions, and a boolean for player presence
        # [player bool, map, upbool, rightbool, downbool, leftbool]
        self.map = [[[rooms[3]]]]
        
                #   [[[], [p], []],
                #    [[], [p], []],
                #    [[], [], []]]    
                
                
        # player will have location and orientation of player, used in update screen method [maprow, mapcolumn, direction, screenrow, screencolumn]
    player = [0, 0, "U", 4, 4]
        
    rooms = [[["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"], ["U", "L", "R"]],
             
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"], ["L", "R"]],
              
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["U", "D"]],
             
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["U", "D", "L", "R"]],
            
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D", "R"]],
            
            
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["R", "D"]],
            
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["R", "D", "U"]],
            
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D", "U"]],
            
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"], ["R", "U"]],
            
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"], ["L", "U"]],
            
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D"]]]

###############################################################################
###############################################################################
    
    def move(self, direction):
        # checks to see if the player can move a certain way and will return a boolean if true. Accepts "U", "D", "L", "R" as unputs
#######################Up########################################################

        if direction == "U":
            if player[3] == 0 and player[0] == 0:
                #Makes map taller
                expandUp()
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "D":
                            plausable.append(rooms[i]) 
                self.map[0][player[1]] = plausable[random.randint(0, len(plausable))]
                # alters player
                player[0] = player[0] - 1
                player[3] = 8
                
            elif player[3] == 0 and self.map[player[0]-1][player[1]] == []:
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "D":
                            plausable.append(rooms[i]) 
                self.map[0][player[1]] = plausable[random.randint(0, len(plausable))]
                # alters player
                player[0] = player[0] - 1
                player[3] = 8
            
            elif player[3] == 0:
                player[0] = player[0] - 1
                player[3] = 8
            else:
                player[3] = player[3] - 1
                
#######################Down#########################################################################
                
        elif direction == "D":
            if player[3] == 8 and player[0] == len(self.map)-1:
                #Makes map downerer(?)
                expandDown()
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "U":
                            plausable.append(rooms[i]) 
                self.map[len(self.map)-1][player[1]] = plausable[random.randint(0, len(plausable))]
                # alters player
                player[0] = player[0] + 1
                player[3] = 0
                
            elif player[3] == 8 and self.map[player[0]+1][player[1]] == []:
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "U":
                            plausable.append(rooms[i]) 
                self.map[0][player[1]] = plausable[random.randint(0, len(plausable))]
                # alters player
                player[0] = player[0] + 1
                player[3] = 0
            
            elif player[3] == 8:
                player[0] = player[0] + 1
                player[3] = 0
            else:
                player[3] = player[3] + 1
                
#######################Left####################################################################

        elif direction == "L":
            if player[4] == 0 and player[1] == 0:
                #Makes map lefter
                expandLeft()
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "R":
                            plausable.append(rooms[i]) 
                self.map[player[0]][player[1]-1] = plausable[random.randint(0, len(plausable))]
                # alters player
                player[1] = player[1] - 1
                player[4] = 8
                
            elif player[4] == 0 and self.map[player[0]][player[1] - 1] == []:
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "R":
                            plausable.append(rooms[i]) 
                self.map[player[0]][player[1]-1] = plausable[random.randint(0, len(plausable))]
                # alters player
                player[1] = player[1] - 1
                player[4] = 8
            
            elif player[4] == 0:
                player[1] = player[1] - 1
                player[4] = 8
            else:
                player[4] = player[4] - 1
        
#######################Right#####################################################

        elif direction == "R":
            if player[4] == 8 and player[1] == len(self.map[0])-1:
                #Makes map righter(?)
                expandRight()
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "L":
                            plausable.append(rooms[i]) 
                self.map[player[0]][player[1]+1] = plausable[random.randint(0, len(plausable)-1)]
                # alters player
                player[1] = player[1] + 1
                player[4] = 0
                
            elif player[4] == 8 and self.map[player[0]][player[1] + 1] == []:
                # makes room
                # compiles list of possibilities
                plausable = []
                for i in range(len(rooms)):
                    for x in range(len(rooms[i][-1])):
                        if rooms[i][-1][x] == "L":
                            plausable.append(rooms[i]) 
                self.map[player[0]][player[1]+1] = plausable[random.randint(0, len(plausable)-1)]
                # alters player
                player[1] = player[1] + 1
                player[4] = 0
            
            elif player[4] == 8:
                player[1] = player[1] + 1
                player[4] = 0
            else:
                player[4] = player[4] + 1
                
############################################################################
############################################################################

        
    def printScreenAndPlayer(self):
        screen = self.map[player[0]][player[1]][0]
        #print(screen)
        screen[player[3]][player[4]] = "P"
        for r in range(0,9):
            line = ""
            for c in range(0,9):
                line = line + screen[r][c] + " "
            print(line)
        screen[player[3]][player[4]] = " "
            
 
    def expandRight(self):
        # add a layer to self.map on the right
        for i in range(0,len(self.map)):
            self.map[i].append([])
            

    def expandLeft(self):
        # add a layer to self.map on the right
        for i in range(0,len(self.map)):
            self.map[i].insert(0, [])
        player[1] = player[1] + 1
        
    def expandUp(self):
        insertation = []
        for i in range(0,len(self.map[0])):
            insertation.append([])
        self.map.insert(0, insertation)
        player[0] = player[0] + 1
    
    def expandDown(self):
        insertation = []
        for i in range(0,len(self.map[0])):
            insertation.append([])
        self.map.append(insertation)

        

myGame = worldMap()        

player = [0, 0, "U", 4, 4]

while True:
    myGame.printScreenAndPlayer() 
    #print(myGame.map)
    data = input("")
    if data == "w":
        myGame.move("U")
    elif data == "a":
        myGame.move("L")        
    elif data == "s":
         myGame.move("D")       
    elif data == "d":
        myGame.move("R")        
    elif data == "x":
        break
        
    myGame.printScreenAndPlayer()
# Out:
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#         P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# d
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#           P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#           P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# d
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#             P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#             P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# d
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#               P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #
#
#               P
#
# # # #       # # #
# # # #       # # #
# # # #       # # #
# d
# ...

# %% [markdown]
# ## The below items are just testing and not the final project at all.
#
# #
# #
# #
# #

# %%
screen = [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D"]]

maps = [[["Start "]]]
player = [0, 0, "U", 4, 4]

def expandUp():
    insertation = []
    for i in range(0,len(maps[0])):
        insertation.append([])
    maps.insert(0, insertation)
    player[0] = player[0] + 1
    
def expandRight():
        # add a layer to self.map on the right
    for i in range(0,len(maps)):
        maps[i].append([])
            

def expandLeft():
        # add a layer to self.map on the right
    for i in range(0,len(maps)):
        maps[i].insert(0, [])
    player[1] = player[1] + 1
    
def expandDown():
    insertation = []
    for i in range(0,len(maps[0])):
        insertation.append([])
    maps.append(insertation)
    
while True:
    print(player)
    print(maps)
    data = input("")
    if data == "w":
        expandUp()
    elif data == "a":
        expandLeft()        
    elif data == "s":
        expandDown()      
    elif data == "d":
        expandRight()        
    elif data == "x":
        break
# Out:
# [0, 0, 'U', 4, 4]
# [[['Start ']]]
# w
# [1, 0, 'U', 4, 4]
# [[[]], [['Start ']]]
# d
# [1, 0, 'U', 4, 4]
# [[[], []], [['Start '], []]]
# a
# [1, 1, 'U', 4, 4]
# [[[], [], []], [[], ['Start '], []]]
# a
# [1, 2, 'U', 4, 4]
# [[[], [], [], []], [[], [], ['Start '], []]]
# w
# [2, 2, 'U', 4, 4]
# [[[], [], [], []], [[], [], [], []], [[], [], ['Start '], []]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[152], line 42
#      40 print(player)
#      41 print(maps)
# ---> 42 data = input("")
#      43 if data == "w":
#      44     expandUp()
#
# File D:\RandomFolder\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
# ...

# %%
i = -50
plausable = [1, 2, 3, 4, 5, 6, 7, 8, 9]
while i < 10:
    print(random.randint(0, len(plausable)-1))
    
    i = i + 1
# Out:
# 1
# 8
# 0
# 6
# 8
# 5
# 5
# 7
# 0
# 3
# 0
# 2
# 1
# 1
# 3
# 3
# 1
# 8
# 7
# 4
# 0
# 5
# 1
# 2
# 2
# 2
# 2
# 7
# 4
# 1
# 5
# 3
# 0
# 6
# 8
# 7
# 6
# 5
# 4
# 3
# 5
# 3
# 1
# 4
# 4
# 6
# 5
# 5
# 6
# 7
# 4
# 1
# 8
# 6
# 6
# 8
# 5
# 7
# 1
# 5

# %%
screen = [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D"]]

maps = [[[screen]]]
player = [0, 0, "U", 4, 4]

def printScreenAndPlayer():
        screen = maps[player[0]][player[1]][0]
        print(screen)
        screen[player[3]][player[4]] = "P"
        for r in range(0,9):
            line = ""
            for c in range(0,9):
                line = line + screen[r][c] + " "
            print(line)
        #screen[player[3]][player[4]] = " "
        
printScreenAndPlayer()

#print(maps,"\n\n")
#print(maps[0],"\n\n")
#print(maps[0][0][0],"\n\n")
# Out:
# [['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], [' ', ' ', ' ', ' ', ' ', ' ', '#', '#', '#'], [' ', ' ', ' ', ' ', ' ', ' ', '#', '#', '#'], [' ', ' ', ' ', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['L', 'D']]
# # # # # # # # # #
# # # # # # # # # #
# # # # # # # # # #
#             # # #
#         P   # # #
#             # # #
# # # #       # # #
# # # #       # # #
# # # #       # # #

# %%
def expandRight():
        # add a layer to self.map on the right
    for i in range(0,len(maps)):
        maps[i].append([])

def expandLeft():
        # add a layer to self.map on the right
    for i in range(0,len(maps)):
        maps[i].insert(0, [])
        
def expandUp():
    insertation = []
    for i in range(0,len(maps[0])):
        insertation.append([])
    maps.insert(0, insertation)
    
def expandDown():
    insertation = []
    for i in range(0,len(maps[0])):
        insertation.append([])
    maps.append(insertation)
    
maps = [[["Hello"]]]

while True:
    print(maps)
    data = input("")
    if data == "w":
        expandUp()
    elif data == "a":
        expandLeft()        
    elif data == "s":
        expandDown()      
    elif data == "d":
        expandRight()        
    elif data == "x":
        break
# Out:
# [[['Hello']]]
# w
# [[[]], [['Hello']]]
# d
# [[[], []], [['Hello'], []]]
# s
# [[[], []], [['Hello'], []], [[], []]]
# s
# [[[], []], [['Hello'], []], [[], []], [[], []]]
# d
# [[[], [], []], [['Hello'], [], []], [[], [], []], [[], [], []]]
# a
# [[[], [], [], []], [[], ['Hello'], [], []], [[], [], [], []], [[], [], [], []]]
# d
# [[[], [], [], [], []], [[], ['Hello'], [], [], []], [[], [], [], [], []], [[], [], [], [], []]]
# d
# [[[], [], [], [], [], []], [[], ['Hello'], [], [], [], []], [[], [], [], [], [], []], [[], [], [], [], [], []]]
# d
# [[[], [], [], [], [], [], []], [[], ['Hello'], [], [], [], [], []], [[], [], [], [], [], [], []], [[], [], [], [], [], [], []]]
# s
# [[[], [], [], [], [], [], []], [[], ['Hello'], [], [], [], [], []], [[], [], [], [], [], [], []], [[], [], [], [], [], [], []], [[], [], [], [], [], [], []]]
# ---------------------------------------------------------------------------
# ...

# %%
#screen = self.map[player[0]][player[1]]

screen = [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          [" ", " ", " ", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
          ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D"]]

player = [0, 0, "U", 4, 4]

def update():
    #screen = self.map[player[0]][player[1]]
    screen[player[3]][player[4]] = "P"
    for r in range(0,8):
        line = ""
        for c in range(0,8):
            line = line + screen[r][c] + " "
        print(line)
    screen[player[3]][player[4]] = " "
        
while player[0] == 0:
    update()
    data = input("")
    if data == "w":# and myGame.checkValidMove("U"):
        player[3] = player[3] - 1
    elif data == "a":# and myGame.checkValidMove("L"):
        player[4] = player[4] - 1
    elif data == "s":# and myGame.checkValidMove("D"):
        player[3] = player[3] + 1
    elif data == "d":# and myGame.checkValidMove("R"):
        player[4] = player[4] + 1
    elif data == "x":
        break
# Out:
# # # # # # # # #
# # # # # # # # #
# # # # # # # # #
#             # #
#         P   # #
#             # #
# # # #       # #
# # # #       # #
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 27
#      25 while player[0] == 0:
#      26     update()
# ---> 27     data = input("")
#      28     if data == "w":# and myGame.checkValidMove("U"):
#      29         player[3] = player[3] - 1
#
# File D:\RandomFolder\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# ...

# %%
maps = [[["Hi"]]]

def expandRight():
    # add a layer to self.map on the right
    for i in range(0,len(maps)):
        maps[i].append([])

def expandLeft():
    # add a layer to self.map on the right
    for i in range(0,len(maps)):
        maps[i].insert(0, [])
        
def expandUp():
    insertation = []
    for i in range(0,len(maps[0])):
        insertation.append([])
    maps.insert(0, insertation)
    
def expandDown():
    insertation = []
    for i in range(0,len(maps[0])):
        insertation.append([])
    maps.append(insertation)

print(maps[0])
        
expandDown()

print(maps)
# Out:
# [['Hi']]
# [[['Hi']], [[]]]

# %%
rooms = [[["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"], ["U", "L", "R"]],
             
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"], ["L", "R"]],
              
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["U", "D"]],
             
             [["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["U", "D", "L", "R"]],
            
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              [" ", " ", " ", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["L", "D", "R"]],
            
            
             [["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", "#", "#", "#", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", " ", " ", " "],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"],
              ["#", "#", "#", " ", " ", " ", "#", "#", "#"], ["R", "D"]]]

maps = [[[rooms[3]]],
       []]

#reqs = maps[player[0]][player[1]][0][-1]

#if maps[player[0]][player[1]][player[3] + 1][player[4]] == " ":
   # print("It works?")

#print(len(maps))

plausable = []
for i in range(len(rooms)):
    #print(rooms[i])
    for x in range(len(rooms[i][-1])):
        if rooms[i][-1][x] == "R":        
            plausable.append(rooms[i]) 
print(plausable)
# Out:
# [[['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['U', 'L', 'R']], [['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' '], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['#', '#', '#', '#', '#', '#', '#', '#', '#'], ['L', 'R']], [['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' ', ' ', '#', '#', '#'], ['#', '#', '#', ' ', ' 
# ...
